# %% [markdown]
# # Kaggle Challenge 4: Implementing a Convolutional Neural Network on the `CIFAR10` Dataset

# %%
# !echo sourcing our model...
# %cd '../src/'
# Out:
# sourcing our model...
# /Users/jppalacios/academic/fall2023/cis678/ml-challenge-4/src

# %%
import torch
import torchvision
import torchvision.transforms as transforms

import matplotlib.pyplot as plt

import numpy as np

#> import our custom scripts
from model import Model
from logger import Reporter
from utils import download_dataset, visualize
# Out:
# Running PyTorch version 2.1.1 on a mps device

# %%
#
#> create our train data loader
# train_loader = load_data()

model = Model()
# Out:
# PyTorch Model - INFO - creating our PyTorch model

# %%
# example usage:

myReporter = Reporter()

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

batch_size = 32
train_dataset, train_loader, test_dataset, test_loader = download_dataset('CIFAR10', batch_size, transform)

print(train_dataset.classes)

visualize(train_loader)

# classes = ('plane', 'car', 'bird', 'cat',
#            'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# # functions to show an image
# def imshow(img):
#     img = img / 2 + 0.5     # unnormalize
#     npimg = img.numpy()
#     plt.imshow(np.transpose(npimg, (1, 2, 0)))
#     plt.show()


# # get some random training images
# dataiter = iter(train_loader)
# images, labels = next(dataiter)

# # show images
# imshow(torchvision.utils.make_grid(images))
# # print labels
# print(' '.join(f'{classes[labels[j]]:5s}' for j in range(batch_size)))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
